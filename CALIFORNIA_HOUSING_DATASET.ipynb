# %% [markdown]
# ###**CALIFORNIA HOUSING DATASET**

# %% [markdown]
# # INTRODUCTION
# This is the dataset used in the second chapter of Aurélien Géron's recent book 'Hands-On Machine learning with Scikit-Learn and TensorFlow'.
# The data contains information from the 1990 California census.
# The data pertains to the houses found in a given California district and some summary stats about them based on the 1990 census data.

# %% [markdown]
# #AIM:
#
# The main aim is to analyse the California Housing Dataset, to determine the appropriate housing prices and also to determine the median_house prices of California.

# %% [markdown]
# #FEATURES:

# %% [markdown]
# ## longitude:
#
# A measure of how far west a house is,
#
# A more negative value is farther west.
#
# Longitude values range from -180 to +180
#
# Data set min: -124.3
#
# Data set max: -114.3
#
# It is a numerical data type i.e Continuous data.

# %% [markdown]
# ## latitude:
#
# A measure of how far north a house is,
#
# A higher value is farther north.
#
# Latitude values range from -90 to +90
#
# Data set min: 32.5
#
# Data set max: 41.9
#
# It is a numerical data type i.e Continuous data.

# %% [markdown]
# ## housing_median_age:
#
# Median age of a house within a block,
#
# A lower number is a newer building.
#
# Data set min: 1.0
#
# Data set max: 52.0
#
# It is a quantitative data type i.e Continuous data.

# %% [markdown]
# ##total_rooms
#
# Total number of rooms within a block.
#
# Data set min: 2.0
#
# Data set max: 39320.0
#
# It is a quantitative data type i.e Discrete data.

# %% [markdown]
# ##total_bedrooms:
#
# Total number of bedrooms within a block.
#
# Data set min: 1.0
#
# Data set max: 6445.0
#
# It is a quantitative data type i.e Discrete data.

# %% [markdown]
# ##population:
#
# Total number of people residing within a block.
#
# Data set min: 3.0
#
# Data set max: 35682.0
#
# It is a quantitative data type i.e Discrete data.

# %% [markdown]
# ##households:
#
# Total number of households, a group of people residing within a home unit, for a block.
#
# Data set min: 1.0
#
# Data set max: 6082.0
#
# It is a quantitative data type i.e Discrete data.

# %% [markdown]
# ##median_income:
# Median income for households within a block of houses (measured in tens of thousands of US Dollars).
#
# Data set min: 0.49
#
# Data set max: 15.0
#
# It is a numerical data type i.e Continuous data.

# %% [markdown]
# ##median_house_value:
#
# Median house value for households within a block (measured in US Dollars).
#
# Data set min: 14999.0
#
# Data set max: 500001.0
#
# It is a numerical data type i.e Continuous data.

# %% [markdown]
# ##ocean_proximity:
#
# Location of ocean with respect to the land.
#
# It is a categorical data type i.e Nominal data.

# %% [markdown]
# **Min and max values in the table below were obtained from the Exercise notebooks using housing.describe(include="all") on the California Housing data set**

# %% [markdown]
# # **Lets Start The Analysis**:

# %%
import numpy as np  # importing required libraries
import pandas as pd #numpy #pandas #seaborn #matplotlib
import seaborn as sns
import matplotlib.pyplot as plt  
housing = pd.read_excel("https://raw.githubusercontent.com/AritraPal13/California-Housing-Data-Analysis/main/housing.xlsx") # read Crop data files
#print output
housing
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %%
housing.describe(include="all")  #describe(include='all') shows all the statiscal calculation in the data set.
# Out:
#            longitude      latitude  housing_median_age   total_rooms  \
# count   20640.000000  20640.000000        20640.000000  20640.000000
# unique           NaN           NaN                 NaN           NaN
# top              NaN           NaN                 NaN           NaN
# freq             NaN           NaN                 NaN           NaN
# mean     -119.569704     35.631861           28.639486   2635.763081
# std         2.003532      2.135952           12.585558   2181.615252
# min      -124.350000     32.540000            1.000000      2.000000
# 25%      -121.800000     33.930000           18.000000   1447.750000
# 50%      -118.490000     34.260000           29.000000   2127.000000
# 75%      -118.010000     37.710000           37.000000   3148.000000
# max      -114.310000     41.950000           52.000000  39320.000000
#
#         total_bedrooms    population    households  median_income  \
# count     20433.000000  20640.000000  20640.000000   20640.000000
# ...

# %%
housing.dtypes     #.dtypes show all the data type of the features in the data set.
# Out:
# longitude             float64
# latitude              float64
# housing_median_age      int64
# total_rooms             int64
# total_bedrooms        float64
# population              int64
# households              int64
# median_income         float64
# median_house_value      int64
# ocean_proximity        object
# dtype: object

# %% [markdown]
# Everything has a float data type except ocean_proximity which is a object data type

# %% [markdown]
# ##**Problem Statement 1**
# **What is the average median income of the data set and check the distribution of data using appropriate plots. Please explain the distribution of the plot.**

# %%
housing['median_income'].mean()      #mean() function used to get the mean/avergae of desired column
# Out:
# 3.8706710029069766

# %% [markdown]
# Average median income of the data set is 3.9

# %%
sns.displot(housing, x="longitude", bins =50)       #The seaborn.distplot() function accepts the data variable as an argument 
plt.grid(True)                                      #returns the plot with the density distribution.
                                                    #x=Adding labels to the axis of DistPlot

sns.displot(housing, x="latitude", bins =50)
plt.grid(True)

sns.displot(housing, x="housing_median_age", bins =50)
plt.grid(True)

sns.displot(housing, x="total_rooms", bins =50)
plt.grid(True)

sns.displot(housing, x="total_bedrooms", bins =50)
plt.grid(True)

sns.displot(housing, x="population", bins =50)
plt.grid(True)

sns.displot(housing, x="households", bins =50)
plt.grid(True)

sns.displot(housing, x="median_income", bins =50)
plt.grid(True)

sns.displot(housing, x="median_house_value", bins =50)
plt.grid(True)

# %%
housing.hist(bins=50,figsize=(20,20),color = "orangered")
                                                                #Histogram is used to see the distribution of a numerical value
                                                                #fig size to get the figure size and color='' for desired colors on the plot.
plt.show()
#output

# %% [markdown]
# From the above plots we can connclude that:
#
#
# *   housing_median_age and median_house_value has outliers in them.
# *   total_rooms,total_bedrooms,population,households,median_income are of Right skewed.
#
# *   While longitude,latitude,housing_median_age and median_house_value are asymetric.

# %% [markdown]
# ##**Problem Statement 2**
# **Draw an appropriate plot to see the distribution of housing_median_age and explain your observations.**

# %%
plt.hist(housing["housing_median_age"],color='blue')  
                                                             #Histogram is used to see the distribution of a numerical value.
plt.title("Histogram plot(housing_median_age)")    
                                                             # x-axis=housing_median_age
                                                             # y-axis=Frequencies
plt.xlabel("housing_median_age")
plt.ylabel("Frequencies")
                                                             #inclusion of grid lines
plt.grid(True)
                                                             #output
plt.show()

# %% [markdown]
# From the above plot we can find the skewness:
# skewness=3*(Mean-Median)/Standard Deviation #Formula for finding skewness
#
# So skewness=-0.088235
#
# If the skewness is between -0.5 and 0.5 the data are nearly symmetrical.
#
# Hence it is nearly symmetrical.

# %%
print(housing['housing_median_age'].mean())   #Calculation of mean
print(housing['housing_median_age'].median()) #Calculation of median
print(housing['housing_median_age'].std())    #Calculation of standard deviation
# Out:
# 28.639486434108527
# 29.0
# 12.58555761211165

# %% [markdown]
# ##**Problem Statement 3**
# **Show with the help of visualization, how median_income and median_house_values are related?**

# %% [markdown]
# Answer:
# Here we will use scatter plot as we have to show how the two attributes or feautures are related.

# %%
sns.scatterplot(x="median_house_value",y="median_income",color='crimson',data=housing)
                                                    # use the function seaborn to make a scatterplot
# To show the plot                                  #Seaborn is an amazing visualization library for statistical graphics plotting in Python
plt.show()                                          #scatter plot gives a relation between two numerical values.
                                                    #x axis=median_house_value
                                                    #y axis=median_income

# %% [markdown]
# From the above visualization we can analyse that median_house_value is directly proportional to the median income which means with an increase in the median_house_value there is also an increase in the median income.
#
# Also we can see an outlier which is seen in the median_house_value in the above figure.

# %% [markdown]
# ##**Problem Statement 4**
# **Create a data set by deleting the corresponding examples from the data set for which total_bedrooms are not available.**

# %%
h1=housing[housing['total_bedrooms'].isnull()]   #Using isnull() to select all rows with NaN under a single DataFrame column:
h1                                              #Here missing values are denoted by NaN
                                                #There are  207 rows of NAN total_bedrooms
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 290      -122.16     37.77                  47         1256             NaN
# 341      -122.17     37.75                  38          992             NaN
# 538      -122.28     37.78                  29         5154             NaN
# 563      -122.24     37.75                  45          891             NaN
# 696      -122.10     37.69                  41          746             NaN
# ...          ...       ...                 ...          ...             ...
# 20267    -119.19     34.20                  18         3620             NaN
# 20268    -119.18     34.19                  19         2393             NaN
# 20372    -118.88     34.17                  15         4260             NaN
# 20460    -118.75     34.29                  17         5512             NaN
# 20484    -118.72     34.28                  17         3051             NaN
#
# ...

# %%
corrected_data=housing.dropna(subset=["total_bedrooms"])
                                        #dropna() method allows the user to analyze and drop Rows/Columns with Null values in different ways.
corrected_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %% [markdown]
# Therefore the missing values in the total_bedrooms are detected and missing values are dropped from the column 'total_bedrooms'by using dropna() method.

# %% [markdown]
# ##**Problem Statement 5**
# **Create a data set by filling the missing data with the mean value of the total_bedrooms in the original data set.**

# %%
print(housing['total_bedrooms'].mean())    #using mean() function to get the mean
# Out:
# 537.8705525375618

# %%
housing["total_bedrooms"]=housing["total_bedrooms"].fillna(housing['total_bedrooms'].mean())  
housing
                                                         #filling the missing value in data set with fillna()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %%
housing[housing['total_bedrooms'].isnull()]   # using isnull to get whether the desired column has "NAN" values.
# Out:
# Empty DataFrame
# Columns: [longitude, latitude, housing_median_age, total_rooms, total_bedrooms, population, households, median_income, median_house_value, ocean_proximity]
# Index: []

# %% [markdown]
# Therefore a new data set has been created where the missing values('NAN') in the 'total_bedrooms' column is replaced with  its mean value.

# %% [markdown]
# ##**Problem Statement 6**
# **Write a programming construct (create a user defined function) to calculate the median value of the data set wherever required.**

# %%
def get_median(sample):                                #created a user defined(get_median) funtion to get median of any data.
     n = len(sample)                                   #len-length of the data set  //-Floor Division  %-Modulus operator
     index = n // 2
     # Sample with an odd number of observations
     if n % 2:
         return sorted(sample)[index]
     # Sample with an even number of observations
     return sum(sorted(sample)[index - 1:index + 1]) / 2

# %%
get_median(housing['longitude'])     #getting the median by user defined function
# Out:
# -118.49

# %%
housing['longitude'].median()     #getting median by using the median() function
# Out:
# -118.49

# %% [markdown]
# ##**Problem Statement 7**
# **Plot latitude versus longitude and explain your observations.**

# %%
sns.scatterplot(x='latitude',y='longitude',color='darkviolet',data=housing) 
                                                     # use the function seaborn to make a scatterplot
                                                     #Seaborn is an amazing visualization library for statistical graphics plotting in Python.
                                                     #scatter plot gives a relation between two numerical values.
                                                     #x axis=latitude   #y axis=longitude
# To show the plot
plt.show()

# %% [markdown]
# We can see that latitude and longitude have a negative corelation with each other.
#
# From the above plot,we can identify that logitude is inversely proportional to latitude.
#
# We can note that with longitude  increasing at y axis while the latitude getting decreased towards origin of x axis.
#
# And aslo latitude increasing towards x axis while longitude is decreasing towards origin of y axis.

# %% [markdown]
# ##**Problem Statement 8**
# **Create a data set for which the ocean_proximity is ‘Near ocean’.**

# %%
housing_nearocean = housing[housing["ocean_proximity"] == "NEAR OCEAN"]

#output                                             #using the filter column (to filter the rows & column 
housing_nearocean                                   #of the data set according to the desired input)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1850     -124.17     41.80                  16         2739           480.0
# 1851     -124.30     41.80                  19         2672           552.0
# 1852     -124.23     41.75                  11         3159           616.0
# 1853     -124.21     41.77                  17         3461           722.0
# 1854     -124.19     41.78                  15         3140           714.0
# ...          ...       ...                 ...          ...             ...
# 20380    -118.83     34.14                  16         1316           194.0
# 20381    -118.83     34.14                  16         1956           312.0
# 20423    -119.00     34.08                  17         1822           438.0
# 20424    -118.75     34.18                   4        16704          2704.0
# 20425    -118.75     34.17                  18         6217           858.0
#
# ...

# %% [markdown]
# ##**Problem Statement 9**
# **Find the mean and median of the median income for the data set created in question 8.**

# %%
print(housing_nearocean['median_income'].mean())   #mean() function gives the averages of the data
# Out:
# 4.0057848006019565

# %%
print(housing_nearocean['median_income'].median())   #median() function  gives the 50th percentile of the data set
# Out:
# 3.64705

# %% [markdown]
# The mean of the 'median_income' on newly created data set i.e housing_nearocean = 4.0057
#
# The median of the 'median_income' on newly created data set i.e housing_nearocean = 3.64705

# %% [markdown]
# ##**Problem Statement 10**
# **Please create a new column named total_bedroom_size. If the total bedrooms is 10 or less, it should be quoted as small. If the total bedrooms is 11 or more but less than 1000, it should be medium, otherwise it should be considered large.**

# %%
#conditions
case = [(housing['total_bedrooms'] <=10),                                        
        (housing['total_bedrooms'] >=11)&(housing['total_bedrooms'] <=1000),
        (housing['total_bedrooms'] > 1000)]
#choicelist
size = ['small','medium','large']                                                #Syntax : numpy.select(condlist, choicelist, default = 0)
#numpy.select() function
housing['total_bedroom_size']=np.select(case,size)                              
#numpy.select() function return an array drawn from elements in choicelist, depending on conditions.
#output
housing
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %% [markdown]
# We have created a new column called 'total_bedroom_size' which is based on the number of total_bedrooms.
#
# If
#
# total_bedrooms<=10 then total_bedroom_size=small
#
# total_bedrooms>=11 & total_bedrooms<=1000 then total_bedroom_size=medium
#
# total_bedrooms>1000 then total_bedroom_size=large

# %% [markdown]
# # CONCLUSION
#
#
#
# *   We have used different type of graphical plots such as scatterplot and histrogram.
# *   We have leart the uses of pandas,numpy,seaborn,matplotlib libraries and conducted different operations using them.
#
# *   We also found outliers from the given data set on features such as housing_median_age and median_house_value.
# *   We alo found median_house_value is directly proportional to the median income.
#
# *  Also latitude and longitude have a negative corelation with each other.
